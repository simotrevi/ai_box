# %% [markdown]
# #NEURAL NETWORKS AND DEEP LEARNING
# > M.Sc. ICT FOR LIFE AND HEALTH
# >
# > Department of Information Engineering
#
# > M.Sc. COMPUTER ENGINEERING
# >
# > Department of Information Engineering
#
# > M.Sc. AUTOMATION ENGINEERING
# >
# > Department of Information Engineering
#
# > M.Sc. PHYSICS OF DATA
# >
# > Department of Physics and Astronomy
#
# > M.Sc. COGNITIVE NEUROSCIENCE AND CLINICAL NEUROPSYCHOLOGY
# >
# > Department of General Psychology
#
# ---
# A.A. 2020/21 (6 CFU) - Dr. Alberto Testolin, Dr. Matteo Gadaleta
# ---

# %% [markdown]
# # Homework 3 - Deep Reinforcement Learning
# # Simone trevisan 1238612

# %% [markdown]
# # DQN - LunarLander: quantitative input

# %% [markdown]
# ## Environment initialization

# %%
# !pip install gym
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (0.17.3)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.5.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym) (1.19.5)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)

# %%
import random
import torch
import numpy as np
import gym
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

from torch import nn
from collections import deque # this python module implements exactly what we need for the replay memeory

# %%
# !apt update
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# !pip install piglet
# !pip3 install box2d-py
# Out:
# Get:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:4 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:6 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:7 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:8 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Ign:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:10 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,708 kB]
# Ign:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:13 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:14 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [874 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,376 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,872 kB]
# Fetched 6,097 kB in 2s (3,012 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 44 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-opengl is already the newest version (3.1.0+dfsg-1).
# 0 upgraded, 0 newly installed, 0 to remove and 44 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# xvfb is already the newest version (2:1.19.6-1ubuntu4.8).
# 0 upgraded, 0 newly installed, 0 to remove and 44 not upgraded.
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.6/dist-packages (2.0)
# Requirement already satisfied: EasyProcess in /usr/local/lib/python3.6/dist-packages (from pyvirtualdisplay) (0.3)
# Requirement already satisfied: piglet in /usr/local/lib/python3.6/dist-packages (1.0.0)
# Requirement already satisfied: piglet-templates in /usr/local/lib/python3.6/dist-packages (from piglet) (1.1.0)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.6/dist-packages (from piglet-templates->piglet) (1.6.3)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.6/dist-packages (from piglet-templates->piglet) (1.1.1)
# Requirement already satisfied: Parsley in /usr/local/lib/python3.6/dist-packages (from piglet-templates->piglet) (1.3)
# Requirement already satisfied: attrs in /usr/local/lib/python3.6/dist-packages (from piglet-templates->piglet) (20.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from astunparse->piglet-templates->piglet) (0.36.2)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from astunparse->piglet-templates->piglet) (1.15.0)
# Requirement already satisfied: box2d-py in /usr/local/lib/python3.6/dist-packages (2.3.8)

# %%
import glob
import io
import base64
import os
from IPython.display import HTML
from IPython import display as ipythondisplay
from pyvirtualdisplay import Display
from gym.wrappers import Monitor

# %%
display = Display(visible=0, size=(1400, 900))
display.start()

# %%
# This code creates a virtual display to draw game images on. 
# If you are running locally, just ignore it
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY"))==0:
    # !bash ../xvfb start
    # %env DISPLAY=:1

# %%
"""
Utility functions to enable video recording of gym environment and displaying it
To enable video, just do "env = wrap_env(env)""
"""

def show_videos():
  mp4list = glob.glob('video/*.mp4')
  mp4list.sort()
  for mp4 in mp4list:
    print(f"\nSHOWING VIDEO {mp4}")
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
    
def wrap_env(env, video_callable=None):
  env = Monitor(env, './video', force=True, video_callable=video_callable)
  return env

# %% [markdown]
# ## Experience replay (Replay Memory)

# %%
class ReplayMemory(object):

    def __init__(self, capacity):
        self.memory = deque(maxlen=capacity) # Define a queue with maxlen "capacity"

    def push(self, state, action, next_state, reward):
        self.memory.append( (state, action, next_state, reward) ) # Add the tuple (state, action, next_state, reward) to the queue

    def sample(self, batch_size):
        batch_size = min(batch_size, len(self)) # Get all the samples if the requested batch_size is higher than the number of sample currently in the memory
        return random.sample(self.memory, batch_size) # Randomly select "batch_size" samples

    def __len__(self):
        return len(self.memory) # Return the number of samples currently stored in the memory

# %% [markdown]
# ## Policy network

# %% [markdown]
# ### Network definition

# %%
class DQN(nn.Module):

    def __init__(self, state_space_dim, action_space_dim):
        super().__init__()

        self.linear = nn.Sequential(
                nn.Linear(state_space_dim, 150),
                nn.ReLU(),
                nn.Linear(150, 120),
                nn.ReLU(),
                nn.Linear(120, action_space_dim)
                )

    def forward(self, x):
        return self.linear(x)

# %% [markdown]
# ### Exploration Policy

# %% [markdown]
# #### Epsilon-greedy policy

# %%
def choose_action_epsilon_greedy(net, state, epsilon):
    
    if epsilon > 1 or epsilon < 0:
        raise Exception('The epsilon value must be between 0 and 1')
                
    # Evaluate the network output from the current state
    with torch.no_grad():
        net.eval()
        state = torch.tensor(state, dtype=torch.float32) # Convert the state to tensor
        net_out = net(state)

    # Get the best action (argmax of the network output)
    best_action = int(net_out.argmax())
    # Get the number of possible actions
    action_space_dim = net_out.shape[-1]

    # Select a non optimal action with probability epsilon, otherwise choose the best action
    if random.random() < epsilon:
        # List of non-optimal actions
        non_optimal_actions = [a for a in range(action_space_dim) if a != best_action]
        # Select randomly
        action = random.choice(non_optimal_actions)
    else:
        # Select best action
        action = best_action
        
    return action, net_out.numpy()

# %% [markdown]
# #### Softmax policy

# %%
def choose_action_softmax(net, state, temperature):
    
    if temperature < 0:
        raise Exception('The temperature value must be greater than or equal to 0 ')
        
    # If the temperature is 0, just select the best action using the eps-greedy policy with epsilon = 0
    if temperature == 0:
        return choose_action_epsilon_greedy(net, state, 0)
    
    # Evaluate the network output from the current state
    with torch.no_grad():
        net.eval()
        state = torch.tensor(state, dtype=torch.float32)
        net_out = net(state)

    # Apply softmax with temp
    temperature = max(temperature, 1e-8) # set a minimum to the temperature for numerical stability
    softmax_out = nn.functional.softmax(net_out / temperature, dim=0).numpy()
                
    # Sample the action using softmax output as mass pdf
    all_possible_actions = np.arange(0, softmax_out.shape[-1])
    action = np.random.choice(all_possible_actions, p=softmax_out) # this samples a random element from "all_possible_actions" with the probability distribution p (softmax_out in this case)
    
    return action, net_out.numpy()

# %% [markdown]
# #### Exploration profile

# %%
### Define exp exploration profile short
initial_value = 5
num_iterations = 500
exp_decay = np.exp(-np.log(initial_value) / num_iterations * 6) # We compute the exponential decay in such a way the shape of the exploration profile does not depend on the number of iterations
exp_profile_s = [initial_value * (exp_decay ** i) for i in range(num_iterations)]

### Plot exp exploration profile
plt.figure(figsize=(12,8))
plt.plot(exp_profile_s, label='exp profile 500')
plt.legend()
plt.grid()
plt.xlabel('Iteration')
plt.ylabel('Exploration profile')
# Out:
# Text(0, 0.5, 'Exploration profile')

# %% [markdown]
# ## Gym Environment (LunarLander-v2)

# %%
### Create environment
env = gym.make('LunarLander-v2') # Initialize the Gym environment
env.seed(0) # Set a random seed for the environment (reproducible results)

# Get the shapes of the state space (observation_space) and action space (action_space)
state_space_dim = env.observation_space.shape[0]
action_space_dim = env.action_space.n

print(f"STATE SPACE SIZE: {state_space_dim}")
print(f"ACTION SPACE SIZE: {action_space_dim}")
# Out:
# STATE SPACE SIZE: 8
# ACTION SPACE SIZE: 4

# %% [markdown]
# ## Network update

# %% [markdown]
# ### Initialization

# %%
# Set random seeds
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

### PARAMETERS
gamma = 0.99   # gamma parameter for the long term reward
replay_memory_capacity = 100000   # Replay memory capacity
lr = 0.001   # Optimizer learning rate
target_net_update_steps = 1   # Number of episodes to wait before updating the target network
batch_size = 64   # Number of samples to take from the replay memory for each update
bad_state_penalty = 0   # Penalty to the reward when we are in a bad state (in this case when the pole falls down) 
min_samples_for_training = 1000   # Minimum samples in the replay memory to enable the training

# %%
### Initialize the replay memory
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

replay_mem = ReplayMemory(replay_memory_capacity)  

### Initialize the policy network
policy_net = DQN(state_space_dim, action_space_dim)

### Initialize the target network with the same weights of the policy network
target_net = DQN(state_space_dim, action_space_dim)
target_net.load_state_dict(policy_net.state_dict()) # This will copy the weights of the policy network to the target network

### Initialize the optimizer
optimizer = torch.optim.Adam(policy_net.parameters(), lr=lr) # The optimizer will update ONLY the parameters of the policy network

### Initialize the loss function (Huber loss)
loss_fn = nn.SmoothL1Loss()

# %% [markdown]
# ### Update function

# %%
def update_step(policy_net, target_net, replay_mem, gamma, optimizer, loss_fn, batch_size):
        
    # Sample the data from the replay memory
    batch = replay_mem.sample(batch_size)
    batch_size = len(batch)

    # Create tensors for each element of the batch
    states      = torch.tensor([s[0] for s in batch], dtype=torch.float32)
    actions     = torch.tensor([s[1] for s in batch], dtype=torch.int64)
    rewards     = torch.tensor([s[3] for s in batch], dtype=torch.float32)

    # Compute a mask of non-final states (all the elements where the next state is not None)
    non_final_next_states = torch.tensor([s[2] for s in batch if s[2] is not None], dtype=torch.float32) # the next state can be None if the game has ended
    non_final_mask = torch.tensor([s[2] is not None for s in batch], dtype=torch.bool)

    # Compute all the Q values (forward pass)
    policy_net.train()
    q_values = policy_net(states)
    # Select the proper Q value for the corresponding action taken Q(s_t, a)
    state_action_values = q_values.gather(1, actions.unsqueeze(1))

    # Compute the value function of the next states using the target network V(s_{t+1}) = max_a( Q_target(s_{t+1}, a)) )
    with torch.no_grad():
      target_net.eval()
      q_values_target = target_net(non_final_next_states)
    next_state_max_q_values = torch.zeros(batch_size)
    next_state_max_q_values[non_final_mask] = q_values_target.max(dim=1)[0]

    # Compute the expected Q values
    expected_state_action_values = rewards + (next_state_max_q_values * gamma)
    expected_state_action_values = expected_state_action_values.unsqueeze(1) # Set the required tensor shape

    # Compute the Huber loss
    loss = loss_fn(state_action_values, expected_state_action_values)

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    # Apply gradient clipping (clip all the gradients greater than 2 for training stability)
    nn.utils.clip_grad_norm_(policy_net.parameters(), 5)
    optimizer.step()

# %% [markdown]
# ### Training loop

# %%
# Initialize the Gym environment
env = gym.make('LunarLander-v2') 
env.seed(0) # Set a random seed for the environment (reproducible results)
# This is for creating the output video in Colab, not required outside Colab
#env = wrap_env(env, video_callable=lambda episode_id: episode_id % 100 == 0) # Save a video every 100 episodes
mov_avg = []
wnd = deque(maxlen=50)
scores_l = []
for episode_num, tau in enumerate(tqdm(exp_profile_s)):

    # Reset the environment and get the initial state
    state = env.reset()
    # Reset the score. The final score will be the total amount of steps before the pole falls
    score = 0
    done = False

    # Go on until the pole falls off
    while not done:
      # Choose the action following the policy
      action, q_values = choose_action_softmax(policy_net, state, temperature=tau)
      
      # Apply the action and get the next state, the reward and a flag "done" that is True if the game is ended
      next_state, reward, done, info = env.step(action)


      # Update the final score (+1 for each step)
      score += reward

      # Apply penalty for bad state
      if done: # if the pole has fallen down 
          reward += bad_state_penalty
          next_state = None

      # Update the replay memory
      replay_mem.push(state, action, next_state, reward)

      # Update the network
      if len(replay_mem) > min_samples_for_training: # we enable the training only if we have enough samples in the replay memory, otherwise the training will use the same samples too often
          update_step(policy_net, target_net, replay_mem, gamma, optimizer, loss_fn, batch_size)

      # Visually render the environment (disable to speed up the training)
      #env.render()

      # Set the current state for the next iteration
      state = next_state

    # Update the target network every target_net_update_steps episodes
    if episode_num % target_net_update_steps == 0:
        print('Updating target network...')
        target_net.load_state_dict(policy_net.state_dict()) # This will copy the weights of the policy network to the target network

    # Print the final score
    scores_l.append(score)
    wnd.append(score)
    mov_avg.append(np.mean(wnd))
    print(f"EPISODE: {episode_num + 1} - FINAL SCORE: {score} - Temperature: {tau}") # Print the final score

env.close()
### Plot exp exploration profile
plt.figure(figsize=(12,8))
plt.plot(scores_l, label='exp profile scores')
plt.plot(mov_avg, label='Moving average 50')
#plt.plot(scores_s, label='exp profile scores')
#plt.plot(scores_str, label='modified exp profile scores')
plt.legend()
plt.grid()
plt.xlabel('Iteration')
plt.ylabel('Scores')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=500.0), HTML(value='')))
# Updating target network...
# EPISODE: 1 - FINAL SCORE: -100.7629915286771 - Temperature: 5.0
# Updating target network...
# EPISODE: 2 - FINAL SCORE: -187.01242124613853 - Temperature: 4.904360255437023
# Updating target network...
# EPISODE: 3 - FINAL SCORE: -101.92196704890387 - Temperature: 4.8105499030220615
# Updating target network...
# EPISODE: 4 - FINAL SCORE: -80.41108857577345 - Temperature: 4.718533950235565
# Updating target network...
# EPISODE: 5 - FINAL SCORE: -219.91514897221037 - Temperature: 4.628278073893113
# Updating target network...
# EPISODE: 6 - FINAL SCORE: -63.95801164757781 - Temperature: 4.539748607342401
# Updating target network...
# EPISODE: 7 - FINAL SCORE: -349.1730043588874 - Temperature: 4.45291252790513
# Updating target network...
# EPISODE: 8 - FINAL SCORE: -201.47891741982443 - Temperature: 4.367737444559105
# Updating target network...
# EPISODE: 9 - FINAL SCORE: -207.02306829005326 - Temperature: 4.2841915858559485
# Updating target network...
# EPISODE: 10 - FINAL SCORE: -140.04505284749186 - Temperature: 4.202243788069925
# Updating target network...
# EPISODE: 11 - FINAL SCORE: -239.82893978821846 - Temperature: 4.121863483573453
# Updating target network...
# EPISODE: 12 - FINAL SCORE: -59.26563065236595 - Temperature: 4.043020689434968
# Updating target network...
# EPISODE: 13 - FINAL SCORE: -92.17756213215434 - Temperature: 3.96568599623489
# Updating target network...
# EPISODE: 14 - FINAL SCORE: -63.813630680926124 - Temperature: 3.889830557095515
# Updating target network...
# EPISODE: 15 - FINAL SCORE: -43.435263636994634 - Temperature: 3.81542607692074
# Updating target network...
# EPISODE: 16 - FINAL SCORE: -219.89168249094777 - Temperature: 3.742444801841616
# Updating target network...
# EPISODE: 17 - FINAL SCORE: -171.06288505232715 - Temperature: 3.670859508863782
# Updating target network...
# EPISODE: 18 - FINAL SCORE: -83.30920265059815 - Temperature: 3.6006434957129207
# Updating target network...
# EPISODE: 19 - FINAL SCORE: -128.73303723401565 - Temperature: 3.5317705708744556
# Updating target network...
# EPISODE: 20 - FINAL SCORE: -41.101483266685065 - Temperature: 3.4642150438237613
# Updating target network...
# EPISODE: 21 - FINAL SCORE: -86.06285229344061 - Temperature: 3.3979517154432566
# Updating target network...
# EPISODE: 22 - FINAL SCORE: -85.07777924389192 - Temperature: 3.3329558686227925
# Updating target network...
# EPISODE: 23 - FINAL SCORE: -90.77515640437232 - Temperature: 3.269203259039841
# Updating target network...
# EPISODE: 24 - FINAL SCORE: -60.448323556811076 - Temperature: 3.2066701061160368
# Updating target network...
# EPISODE: 25 - FINAL SCORE: -23.3438532809934 - Temperature: 3.145333084146703
# Updating target network...
# EPISODE: 26 - FINAL SCORE: -86.34819422093973 - Temperature: 3.085169313600049
# Updating target network...
# EPISODE: 27 - FINAL SCORE: -45.74118861501012 - Temperature: 3.0261563525828006
# Updating target network...
# EPISODE: 28 - FINAL SCORE: -36.65462424364219 - Temperature: 2.9682721884690713
# Updating target network...
# EPISODE: 29 - FINAL SCORE: -33.005961719152765 - Temperature: 2.911495229689357
# Updating target network...
# EPISODE: 30 - FINAL SCORE: -85.25097185079778 - Temperature: 2.8558042976765945
# Updating target network...
# EPISODE: 31 - FINAL SCORE: -63.78846274885669 - Temperature: 2.8011786189662664
# Updating target network...
# EPISODE: 32 - FINAL SCORE: -47.48704609108872 - Temperature: 2.747597817447626
# Updating target network...
# EPISODE: 33 - FINAL SCORE: -81.45064328947092 - Temperature: 2.6950419067631293
# Updating target network...
# EPISODE: 34 - FINAL SCORE: -67.28823587305192 - Temperature: 2.6434912828532604
# Updating target network...
# EPISODE: 35 - FINAL SCORE: -53.550446279368515 - Temperature: 2.5929267166439525
# Updating target network...
# EPISODE: 36 - FINAL SCORE: -21.409975602312528 - Temperature: 2.5433293468738833
# Updating target network...
# EPISODE: 37 - FINAL SCORE: -37.09150841735365 - Temperature: 2.4946806730589755
# Updating target network...
# EPISODE: 38 - FINAL SCORE: -47.631095272566206 - Temperature: 2.4469625485914643
# Updating target network...
# EPISODE: 39 - FINAL SCORE: -75.14527809315318 - Temperature: 2.4001571739709733
# Updating target network...
# EPISODE: 40 - FINAL SCORE: -59.85276507161353 - Temperature: 2.354247090165057
# Updating target network...
# EPISODE: 41 - FINAL SCORE: -44.29647570345638 - Temperature: 2.3092151720967538
# Updating target network...
# EPISODE: 42 - FINAL SCORE: -53.925773940122795 - Temperature: 2.2650446222566973
# Updating target network...
# EPISODE: 43 - FINAL SCORE: -18.964136299462567 - Temperature: 2.2217189644374224
# Updating target network...
# EPISODE: 44 - FINAL SCORE: -73.13495952379867 - Temperature: 2.179222037587519
# Updating target network...
# EPISODE: 45 - FINAL SCORE: -36.431951611278436 - Temperature: 2.1375379897833433
# Updating target network...
# EPISODE: 46 - FINAL SCORE: -57.93319384233517 - Temperature: 2.096651272316036
# Updating target network...
# EPISODE: 47 - FINAL SCORE: -41.41242549328856 - Temperature: 2.056546633891647
# Updating target network...
# EPISODE: 48 - FINAL SCORE: -45.88193530485238 - Temperature: 2.017209114942198
# Updating target network...
# EPISODE: 49 - FINAL SCORE: -34.48140351167551 - Temperature: 1.978624042045562
# Updating target network...
# EPISODE: 50 - FINAL SCORE: -17.762346256905033 - Temperature: 1.9407770224520815
# Updating target network...
# EPISODE: 51 - FINAL SCORE: -53.13676664830378 - Temperature: 1.9036539387158793
# Updating target network...
# EPISODE: 52 - FINAL SCORE: -39.495144866404125 - Temperature: 1.8672409434288615
# Updating target network...
# EPISODE: 53 - FINAL SCORE: -75.76663251098441 - Temperature: 1.8315244540554478
# Updating target network...
# EPISODE: 54 - FINAL SCORE: -14.60830596368234 - Temperature: 1.7964911478661063
# Updating target network...
# EPISODE: 55 - FINAL SCORE: -2.1018937296381637 - Temperature: 1.7621279569677937
# Updating target network...
# EPISODE: 56 - FINAL SCORE: -42.979621466546476 - Temperature: 1.7284220634294578
# Updating target network...
# EPISODE: 57 - FINAL SCORE: -52.845503883492356 - Temperature: 1.6953608945007768
# Updating target network...
# EPISODE: 58 - FINAL SCORE: -20.95993046824806 - Temperature: 1.6629321179223537
# Updating target network...
# EPISODE: 59 - FINAL SCORE: -91.4881670904076 - Temperature: 1.6311236373256213
# Updating target network...
# EPISODE: 60 - FINAL SCORE: -64.07342707279818 - Temperature: 1.5999235877207303
# Updating target network...
# EPISODE: 61 - FINAL SCORE: 22.94979196205236 - Temperature: 1.5693203310707518
# Updating target network...
# EPISODE: 62 - FINAL SCORE: 22.04364970040399 - Temperature: 1.5393024519505336
# Updating target network...
# EPISODE: 63 - FINAL SCORE: 6.6402499677102185 - Temperature: 1.509858753288591
# Updating target network...
# EPISODE: 64 - FINAL SCORE: -13.65655363388963 - Temperature: 1.4809782521904522
# Updating target network...
# EPISODE: 65 - FINAL SCORE: -38.755968950838735 - Temperature: 1.4526501758418884
# Updating target network...
# EPISODE: 66 - FINAL SCORE: -119.40048212161659 - Temperature: 1.4248639574905122
# Updating target network...
# EPISODE: 67 - FINAL SCORE: -23.79319593439429 - Temperature: 1.3976092325042353
# Updating target network...
# EPISODE: 68 - FINAL SCORE: 24.92164059526594 - Temperature: 1.3708758345051228
# Updating target network...
# EPISODE: 69 - FINAL SCORE: -8.662323496767229 - Temperature: 1.3446537915771974
# Updating target network...
# EPISODE: 70 - FINAL SCORE: 2.156679222728542 - Temperature: 1.3189333225467812
# Updating target network...
# EPISODE: 71 - FINAL SCORE: 105.66159747206939 - Temperature: 1.2937048333339867
# Updating target network...
# EPISODE: 72 - FINAL SCORE: 33.29739890486215 - Temperature: 1.2689589133739967
# Updating target network...
# EPISODE: 73 - FINAL SCORE: 63.47271649650102 - Temperature: 1.2446863321067965
# Updating target network...
# EPISODE: 74 - FINAL SCORE: -39.75443146325374 - Temperature: 1.2208780355340523
# Updating target network...
# EPISODE: 75 - FINAL SCORE: 36.55285455562577 - Temperature: 1.197525142841847
# Updating target network...
# EPISODE: 76 - FINAL SCORE: -24.677161267849602 - Temperature: 1.1746189430880198
# Updating target network...
# EPISODE: 77 - FINAL SCORE: -35.51947276869705 - Temperature: 1.1521508919528656
# Updating target network...
# EPISODE: 78 - FINAL SCORE: -22.324805596746096 - Temperature: 1.1301126085519901
# Updating target network...
# EPISODE: 79 - FINAL SCORE: -13.78615905723907 - Temperature: 1.1084958723101277
# Updating target network...
# EPISODE: 80 - FINAL SCORE: -44.02250709648728 - Temperature: 1.087292619894757
# Updating target network...
# EPISODE: 81 - FINAL SCORE: 69.67262319707206 - Temperature: 1.0664949422083683
# Updating target network...
# EPISODE: 82 - FINAL SCORE: 2.653191418910242 - Temperature: 1.0460950814382652
# Updating target network...
# EPISODE: 83 - FINAL SCORE: -39.41682586771533 - Temperature: 1.026085428162797
# Updating target network...
# EPISODE: 84 - FINAL SCORE: -1.3425274306598687 - Temperature: 1.0064585185129404
# Updating target network...
# EPISODE: 85 - FINAL SCORE: -8.093037552996236 - Temperature: 0.9872070313881786
# Updating target network...
# EPISODE: 86 - FINAL SCORE: -8.360792830865176 - Temperature: 0.9683237857256306
# Updating target network...
# EPISODE: 87 - FINAL SCORE: -43.291580906084285 - Temperature: 0.9498017378214199
# Updating target network...
# EPISODE: 88 - FINAL SCORE: -24.42852432391649 - Temperature: 0.9316339787032777
# Updating target network...
# EPISODE: 89 - FINAL SCORE: -13.36128391032492 - Temperature: 0.9138137315534034
# Updating target network...
# EPISODE: 90 - FINAL SCORE: 62.72464714749023 - Temperature: 0.8963343491806218
# Updating target network...
# EPISODE: 91 - FINAL SCORE: 18.7430035720302 - Temperature: 0.8791893115408905
# Updating target network...
# EPISODE: 92 - FINAL SCORE: -1.3947824265807363 - Temperature: 0.8623722233052367
# Updating target network...
# EPISODE: 93 - FINAL SCORE: 50.23510612393911 - Temperature: 0.8458768114742128
# Updating target network...
# EPISODE: 94 - FINAL SCORE: 98.2647434512059 - Temperature: 0.8296969230379851
# Updating target network...
# EPISODE: 95 - FINAL SCORE: 123.52447547000195 - Temperature: 0.8138265226811771
# Updating target network...
# EPISODE: 96 - FINAL SCORE: 70.7122449676925 - Temperature: 0.7982596905316164
# Updating target network...
# EPISODE: 97 - FINAL SCORE: 25.068228481042816 - Temperature: 0.7829906199521436
# Updating target network...
# EPISODE: 98 - FINAL SCORE: 141.36149514006078 - Temperature: 0.7680136153746576
# Updating target network...
# EPISODE: 99 - FINAL SCORE: 118.42305633083963 - Temperature: 0.7533230901755936
# Updating target network...
# EPISODE: 100 - FINAL SCORE: 91.20794900619438 - Temperature: 0.7389135645920364
# Updating target network...
# EPISODE: 101 - FINAL SCORE: 96.99704854739878 - Temperature: 0.7247796636776962
# Updating target network...
# EPISODE: 102 - FINAL SCORE: 81.57259663648973 - Temperature: 0.7109161152979814
# Updating target network...
# EPISODE: 103 - FINAL SCORE: 100.06267236508667 - Temperature: 0.6973177481634207
# Updating target network...
# EPISODE: 104 - FINAL SCORE: 141.74926946663157 - Temperature: 0.6839794899007048
# Updating target network...
# EPISODE: 105 - FINAL SCORE: 115.43737979849945 - Temperature: 0.6708963651606212
# Updating target network...
# EPISODE: 106 - FINAL SCORE: 123.24880972752008 - Temperature: 0.6580634937621831
# Updating target network...
# EPISODE: 107 - FINAL SCORE: 30.910567703156516 - Temperature: 0.645476088872256
# Updating target network...
# EPISODE: 108 - FINAL SCORE: 167.5261662290633 - Temperature: 0.6331294552200056
# Updating target network...
# EPISODE: 109 - FINAL SCORE: 141.69793299750057 - Temperature: 0.6210189873454981
# Updating target network...
# EPISODE: 110 - FINAL SCORE: 128.40658894029454 - Temperature: 0.6091401678818018
# Updating target network...
# EPISODE: 111 - FINAL SCORE: 119.92415340915397 - Temperature: 0.5974885658699489
# Updating target network...
# EPISODE: 112 - FINAL SCORE: 132.93710910716436 - Temperature: 0.5860598351061288
# Updating target network...
# EPISODE: 113 - FINAL SCORE: 155.4767137329724 - Temperature: 0.5748497125204948
# Updating target network...
# EPISODE: 114 - FINAL SCORE: 124.93609418732655 - Temperature: 0.5638540165869825
# Updating target network...
# EPISODE: 115 - FINAL SCORE: 28.635192971690287 - Temperature: 0.5530686457635452
# Updating target network...
# EPISODE: 116 - FINAL SCORE: 133.62716367169884 - Temperature: 0.5424895769622218
# Updating target network...
# EPISODE: 117 - FINAL SCORE: 65.92762754047416 - Temperature: 0.532112864048473
# Updating target network...
# EPISODE: 118 - FINAL SCORE: 126.36019725949696 - Temperature: 0.5219346363692191
# Updating target network...
# EPISODE: 119 - FINAL SCORE: 135.99483285921804 - Temperature: 0.5119510973090347
# Updating target network...
# EPISODE: 120 - FINAL SCORE: -85.25287098331076 - Temperature: 0.5021585228739602
# Updating target network...
# EPISODE: 121 - FINAL SCORE: 150.92745481126693 - Temperature: 0.49255326030240293
# Updating target network...
# EPISODE: 122 - FINAL SCORE: 138.42963999753974 - Temperature: 0.4831317267026063
# Updating target network...
# EPISODE: 123 - FINAL SCORE: 111.3048255252933 - Temperature: 0.4738904077161849
# Updating target network...
# EPISODE: 124 - FINAL SCORE: 123.99878392042501 - Temperature: 0.4648258562072208
# Updating target network...
# EPISODE: 125 - FINAL SCORE: 137.28342159732085 - Temperature: 0.45593469097643563
# Updating target network...
# EPISODE: 126 - FINAL SCORE: 48.98560837678648 - Temperature: 0.4472135954999585
# Updating target network...
# EPISODE: 127 - FINAL SCORE: 114.53048693898012 - Temperature: 0.43865931669221725
# Updating target network...
# EPISODE: 128 - FINAL SCORE: 108.61665513447934 - Temperature: 0.43026866369249456
# Updating target network...
# EPISODE: 129 - FINAL SCORE: 155.27991910509073 - Temperature: 0.4220385066746939
# Updating target network...
# EPISODE: 130 - FINAL SCORE: 162.42428040185192 - Temperature: 0.4139657756798723
# Updating target network...
# EPISODE: 131 - FINAL SCORE: 143.07647523911578 - Temperature: 0.4060474594711049
# Updating target network...
# EPISODE: 132 - FINAL SCORE: 162.49862552424975 - Temperature: 0.3982806044102524
# Updating target network...
# EPISODE: 133 - FINAL SCORE: 120.55504653450403 - Temperature: 0.3906623133562156
# Updating target network...
# EPISODE: 134 - FINAL SCORE: 164.30520908553137 - Temperature: 0.3831897445842616
# Updating target network...
# EPISODE: 135 - FINAL SCORE: 130.76395468445034 - Temperature: 0.3758601107260234
# Updating target network...
# EPISODE: 136 - FINAL SCORE: 165.1014783703384 - Temperature: 0.3686706777297736
# Updating target network...
# EPISODE: 137 - FINAL SCORE: 163.7664157037278 - Temperature: 0.3616187638405866
# Updating target network...
# EPISODE: 138 - FINAL SCORE: 181.32243899187557 - Temperature: 0.354701738600008
# Updating target network...
# EPISODE: 139 - FINAL SCORE: 126.0953613238652 - Temperature: 0.34791702186485834
# Updating target network...
# EPISODE: 140 - FINAL SCORE: 137.48474906160715 - Temperature: 0.3412620828448051
# Updating target network...
# EPISODE: 141 - FINAL SCORE: 163.38572568176417 - Temperature: 0.3347344391583437
# Updating target network...
# EPISODE: 142 - FINAL SCORE: 163.43332101852542 - Temperature: 0.3283316559068367
# Updating target network...
# EPISODE: 143 - FINAL SCORE: 130.95462441174934 - Temperature: 0.3220513447662629
# Updating target network...
# EPISODE: 144 - FINAL SCORE: 176.9755842213788 - Temperature: 0.31589116309634124
# Updating target network...
# EPISODE: 145 - FINAL SCORE: 185.31754816551552 - Temperature: 0.3098488130666941
# Updating target network...
# EPISODE: 146 - FINAL SCORE: 159.6351177178852 - Temperature: 0.3039220407997261
# Updating target network...
# EPISODE: 147 - FINAL SCORE: 162.37680482048114 - Temperature: 0.29810863552989725
# Updating target network...
# EPISODE: 148 - FINAL SCORE: 135.34914829197305 - Temperature: 0.2924064287790779
# Updating target network...
# EPISODE: 149 - FINAL SCORE: -13.891377324618354 - Temperature: 0.28681329354767726
# Updating target network...
# EPISODE: 150 - FINAL SCORE: 114.50342126209091 - Temperature: 0.2813271435212441
# Updating target network...
# EPISODE: 151 - FINAL SCORE: 154.31442776530935 - Temperature: 0.2759459322922434
# Updating target network...
# EPISODE: 152 - FINAL SCORE: 60.07165394777046 - Temperature: 0.2706676525967189
# Updating target network...
# EPISODE: 153 - FINAL SCORE: 168.37308273008017 - Temperature: 0.26549033556555673
# Updating target network...
# EPISODE: 154 - FINAL SCORE: 96.81463397303284 - Temperature: 0.260412049990071
# Updating target network...
# EPISODE: 155 - FINAL SCORE: 162.32302922576255 - Temperature: 0.25543090160163673
# Updating target network...
# EPISODE: 156 - FINAL SCORE: 150.42574048156868 - Temperature: 0.25054503236510245
# Updating target network...
# EPISODE: 157 - FINAL SCORE: 71.46874197255957 - Temperature: 0.24575261978571825
# Updating target network...
# EPISODE: 158 - FINAL SCORE: 145.23598321846288 - Temperature: 0.24105187622932056
# Updating target network...
# EPISODE: 159 - FINAL SCORE: -13.196490435844666 - Temperature: 0.23644104825552087
# Updating target network...
# EPISODE: 160 - FINAL SCORE: 159.31553508737898 - Temperature: 0.2319184159636488
# Updating target network...
# EPISODE: 161 - FINAL SCORE: 152.95989012909808 - Temperature: 0.2274822923512061
# Updating target network...
# EPISODE: 162 - FINAL SCORE: -23.556662173249407 - Temperature: 0.22313102268459217
# Updating target network...
# EPISODE: 163 - FINAL SCORE: 113.3220098426272 - Temperature: 0.21886298388186617
# Updating target network...
# EPISODE: 164 - FINAL SCORE: 12.966223318923483 - Temperature: 0.21467658390731564
# Updating target network...
# EPISODE: 165 - FINAL SCORE: 168.59360698156615 - Temperature: 0.21057026117760602
# Updating target network...
# EPISODE: 166 - FINAL SCORE: 203.13743694728728 - Temperature: 0.20654248397928895
# Updating target network...
# EPISODE: 167 - FINAL SCORE: 167.40156725574758 - Temperature: 0.2025917498974526
# Updating target network...
# EPISODE: 168 - FINAL SCORE: 157.18166311456642 - Temperature: 0.1987165852553008
# Updating target network...
# EPISODE: 169 - FINAL SCORE: 152.38868563773775 - Temperature: 0.19491554456445206
# Updating target network...
# EPISODE: 170 - FINAL SCORE: 131.6079097639661 - Temperature: 0.19118720998575253
# Updating target network...
# EPISODE: 171 - FINAL SCORE: 168.78024161578227 - Temperature: 0.18753019080040342
# Updating target network...
# EPISODE: 172 - FINAL SCORE: 141.79562656085793 - Temperature: 0.18394312289120404
# Updating target network...
# EPISODE: 173 - FINAL SCORE: 144.63233278642153 - Temperature: 0.1804246682337179
# Updating target network...
# EPISODE: 174 - FINAL SCORE: 171.79841357233306 - Temperature: 0.17697351439717135
# Updating target network...
# EPISODE: 175 - FINAL SCORE: 202.58397626762644 - Temperature: 0.1735883740548998
# Updating target network...
# EPISODE: 176 - FINAL SCORE: 173.51769282329036 - Temperature: 0.1702679845041572
# Updating target network...
# EPISODE: 177 - FINAL SCORE: 1.2810358053395134 - Temperature: 0.1670111071951111
# Updating target network...
# EPISODE: 178 - FINAL SCORE: 114.6567832036728 - Temperature: 0.1638165272688471
# Updating target network...
# EPISODE: 179 - FINAL SCORE: 1.1241001723968083 - Temperature: 0.16068305310420977
# Updating target network...
# EPISODE: 180 - FINAL SCORE: 129.05849198010694 - Temperature: 0.15760951587331262
# Updating target network...
# EPISODE: 181 - FINAL SCORE: -64.490241221629 - Temperature: 0.15459476910554903
# Updating target network...
# EPISODE: 182 - FINAL SCORE: 54.654200136033296 - Temperature: 0.15163768825994361
# Updating target network...
# EPISODE: 183 - FINAL SCORE: 143.85228564538502 - Temperature: 0.14873717030568337
# Updating target network...
# EPISODE: 184 - FINAL SCORE: 168.71620322101285 - Temperature: 0.14589213331067227
# Updating target network...
# EPISODE: 185 - FINAL SCORE: 170.2360573440349 - Temperature: 0.1431015160379562
# Updating target network...
# EPISODE: 186 - FINAL SCORE: 156.02959403387888 - Temperature: 0.14036427754986724
# Updating target network...
# EPISODE: 187 - FINAL SCORE: -35.6601748966652 - Temperature: 0.13767939681974004
# Updating target network...
# EPISODE: 188 - FINAL SCORE: 241.0696905649327 - Temperature: 0.1350458723510551
# Updating target network...
# EPISODE: 189 - FINAL SCORE: 140.261045743987 - Temperature: 0.13246272180386726
# Updating target network...
# EPISODE: 190 - FINAL SCORE: 144.72376478630648 - Temperature: 0.12992898162837957
# Updating target network...
# EPISODE: 191 - FINAL SCORE: 166.21082880479491 - Temperature: 0.1274437067055264
# Updating target network...
# EPISODE: 192 - FINAL SCORE: 153.47352984021234 - Temperature: 0.1250059699944313
# Updating target network...
# EPISODE: 193 - FINAL SCORE: 252.97555596598664 - Temperature: 0.12261486218660841
# Updating target network...
# EPISODE: 194 - FINAL SCORE: 37.411079220066796 - Temperature: 0.12026949136677804
# Updating target network...
# EPISODE: 195 - FINAL SCORE: 213.46626914642533 - Temperature: 0.1179689826801705
# Updating target network...
# EPISODE: 196 - FINAL SCORE: -53.80002188706352 - Temperature: 0.11571247800619336
# Updating target network...
# EPISODE: 197 - FINAL SCORE: -25.421278025526092 - Temperature: 0.11349913563834109
# Updating target network...
# EPISODE: 198 - FINAL SCORE: 229.31395436544526 - Temperature: 0.11132812997022719
# Updating target network...
# EPISODE: 199 - FINAL SCORE: 177.50118980377403 - Temperature: 0.1091986511876219
# Updating target network...
# EPISODE: 200 - FINAL SCORE: 119.50026705493251 - Temperature: 0.10710990496638076
# Updating target network...
# EPISODE: 201 - FINAL SCORE: 176.80692440549976 - Temperature: 0.1050611121761509
# Updating target network...
# EPISODE: 202 - FINAL SCORE: 15.981077307774981 - Temperature: 0.10305150858974503
# Updating target network...
# EPISODE: 203 - FINAL SCORE: 176.2505810868398 - Temperature: 0.10108034459807452
# Updating target network...
# EPISODE: 204 - FINAL SCORE: 29.14066778545083 - Temperature: 0.09914688493053503
# Updating target network...
# EPISODE: 205 - FINAL SCORE: 110.46038629517716 - Temperature: 0.0972504083807408
# Updating target network...
# EPISODE: 206 - FINAL SCORE: 19.841363545837027 - Temperature: 0.09539020753750495
# Updating target network...
# EPISODE: 207 - FINAL SCORE: -223.37728731784665 - Temperature: 0.09356558852096569
# Updating target network...
# EPISODE: 208 - FINAL SCORE: 120.65827280781475 - Temperature: 0.09177587072375976
# Updating target network...
# EPISODE: 209 - FINAL SCORE: 157.21910229080154 - Temperature: 0.09002038655714673
# Updating target network...
# EPISODE: 210 - FINAL SCORE: 164.31497530641454 - Temperature: 0.08829848120198955
# Updating target network...
# EPISODE: 211 - FINAL SCORE: 140.1669022713035 - Temperature: 0.08660951236449813
# Updating target network...
# EPISODE: 212 - FINAL SCORE: -23.892819871594355 - Temperature: 0.08495285003664521
# Updating target network...
# EPISODE: 213 - FINAL SCORE: 169.5182301601725 - Temperature: 0.08332787626116492
# Updating target network...
# EPISODE: 214 - FINAL SCORE: 126.13091076280811 - Temperature: 0.08173398490104629
# Updating target network...
# EPISODE: 215 - FINAL SCORE: -207.12277236931297 - Temperature: 0.08017058141343623
# Updating target network...
# EPISODE: 216 - FINAL SCORE: -281.60792014216184 - Temperature: 0.07863708262786698
# Updating target network...
# EPISODE: 217 - FINAL SCORE: 178.7245789426182 - Temperature: 0.0771329165287256
# Updating target network...
# EPISODE: 218 - FINAL SCORE: 229.60345458620608 - Temperature: 0.07565752204188465
# Updating target network...
# EPISODE: 219 - FINAL SCORE: 153.8439713530211 - Temperature: 0.07421034882541393
# Updating target network...
# EPISODE: 220 - FINAL SCORE: 126.95170860676859 - Temperature: 0.07279085706429554
# Updating target network...
# EPISODE: 221 - FINAL SCORE: 124.83194946996875 - Temperature: 0.07139851726906567
# Updating target network...
# EPISODE: 222 - FINAL SCORE: 201.76767753589985 - Temperature: 0.07003281007830793
# Updating target network...
# EPISODE: 223 - FINAL SCORE: 196.43311437059566 - Temperature: 0.06869322606492456
# Updating target network...
# EPISODE: 224 - FINAL SCORE: 99.12369260796521 - Temperature: 0.06737926554611333
# Updating target network...
# EPISODE: 225 - FINAL SCORE: 245.86885893998334 - Temperature: 0.06609043839697909
# Updating target network...
# EPISODE: 226 - FINAL SCORE: 264.17255551162805 - Temperature: 0.06482626386771063
# Updating target network...
# EPISODE: 227 - FINAL SCORE: 129.52003278732082 - Temperature: 0.06358627040425466
# Updating target network...
# EPISODE: 228 - FINAL SCORE: 264.8605153189394 - Temperature: 0.0623699954724196
# Updating target network...
# EPISODE: 229 - FINAL SCORE: 246.14821232888323 - Temperature: 0.06117698538534436
# Updating target network...
# EPISODE: 230 - FINAL SCORE: 176.10181173821348 - Temperature: 0.060006795134266905
# Updating target network...
# EPISODE: 231 - FINAL SCORE: 236.08716147584033 - Temperature: 0.05885898822253008
# Updating target network...
# EPISODE: 232 - FINAL SCORE: 265.0669988569674 - Temperature: 0.057733136502762475
# Updating target network...
# EPISODE: 233 - FINAL SCORE: 271.76615040623767 - Temperature: 0.05662882001717374
# Updating target network...
# EPISODE: 234 - FINAL SCORE: 221.73661999178358 - Temperature: 0.055545626840904694
# Updating target network...
# EPISODE: 235 - FINAL SCORE: 271.00258375802684 - Temperature: 0.05448315292837378
# Updating target network...
# EPISODE: 236 - FINAL SCORE: 257.11478825269023 - Temperature: 0.05344100196256273
# Updating target network...
# EPISODE: 237 - FINAL SCORE: 295.91351630599047 - Temperature: 0.05241878520718493
# Updating target network...
# EPISODE: 238 - FINAL SCORE: 16.262865883795214 - Temperature: 0.05141612136168158
# Updating target network...
# EPISODE: 239 - FINAL SCORE: 271.21731587521884 - Temperature: 0.050432636418991546
# Updating target network...
# EPISODE: 240 - FINAL SCORE: 284.6703496082165 - Temperature: 0.04946796352604158
# Updating target network...
# EPISODE: 241 - FINAL SCORE: 237.26062758571655 - Temperature: 0.04852174284690533
# Updating target network...
# EPISODE: 242 - FINAL SCORE: 242.63449079114739 - Temperature: 0.04759362142857964
# Updating target network...
# EPISODE: 243 - FINAL SCORE: 253.545084170934 - Temperature: 0.04668325306932837
# Updating target network...
# EPISODE: 244 - FINAL SCORE: 238.99062633085944 - Temperature: 0.045790298189544505
# Updating target network...
# EPISODE: 245 - FINAL SCORE: 223.80201942753314 - Temperature: 0.04491442370508239
# Updating target network...
# EPISODE: 246 - FINAL SCORE: 234.13570761153747 - Temperature: 0.04405530290301291
# Updating target network...
# EPISODE: 247 - FINAL SCORE: 270.8764589790089 - Temperature: 0.04321261531975518
# Updating target network...
# EPISODE: 248 - FINAL SCORE: 160.2599121060898 - Temperature: 0.04238604662153926
# Updating target network...
# EPISODE: 249 - FINAL SCORE: 254.51362667298028 - Temperature: 0.041575288487155575
# Updating target network...
# EPISODE: 250 - FINAL SCORE: 271.38286733690086 - Temperature: 0.04078003849294686
# Updating target network...
# EPISODE: 251 - FINAL SCORE: 184.82621891592237 - Temperature: 0.0400000000000001
# Updating target network...
# EPISODE: 252 - FINAL SCORE: 278.66715190900726 - Temperature: 0.03923488204349629
# Updating target network...
# EPISODE: 253 - FINAL SCORE: 217.23787053042525 - Temperature: 0.03848439922417659
# Updating target network...
# EPISODE: 254 - FINAL SCORE: 280.94458174335443 - Temperature: 0.03774827160188462
# Updating target network...
# EPISODE: 255 - FINAL SCORE: 261.6133744471046 - Temperature: 0.037026224591145
# Updating target network...
# EPISODE: 256 - FINAL SCORE: 233.04082249493922 - Temperature: 0.0363179888587393
# Updating target network...
# EPISODE: 257 - FINAL SCORE: 257.12507144675124 - Temperature: 0.035623300223241124
# Updating target network...
# EPISODE: 258 - FINAL SCORE: 257.90965169580045 - Temperature: 0.03494189955647293
# Updating target network...
# EPISODE: 259 - FINAL SCORE: 267.1652718612733 - Temperature: 0.03427353268684767
# Updating target network...
# EPISODE: 260 - FINAL SCORE: 285.43884433413507 - Temperature: 0.03361795030455949
# Updating target network...
# EPISODE: 261 - FINAL SCORE: 262.0135599680739 - Temperature: 0.032974907868587706
# Updating target network...
# EPISODE: 262 - FINAL SCORE: 266.9635296636441 - Temperature: 0.03234416551547983
# Updating target network...
# EPISODE: 263 - FINAL SCORE: 254.08103096730702 - Temperature: 0.0317254879698792
# Updating target network...
# EPISODE: 264 - FINAL SCORE: 318.74566088348604 - Temperature: 0.031118644456764197
# Updating target network...
# EPISODE: 265 - FINAL SCORE: 291.27812947802295 - Temperature: 0.030523408615365993
# Updating target network...
# EPISODE: 266 - FINAL SCORE: -13.87524069911072 - Temperature: 0.029939558414733003
# Updating target network...
# EPISODE: 267 - FINAL SCORE: 269.6919143238575 - Temperature: 0.029366876070910326
# Updating target network...
# EPISODE: 268 - FINAL SCORE: 262.0351714846833 - Temperature: 0.028805147965703437
# Updating target network...
# EPISODE: 269 - FINAL SCORE: 23.663971205345703 - Temperature: 0.028254164566995713
# Updating target network...
# EPISODE: 270 - FINAL SCORE: 299.0882828190728 - Temperature: 0.02771372035059016
# Updating target network...
# EPISODE: 271 - FINAL SCORE: 284.86128088863114 - Temperature: 0.027183613723546118
# Updating target network...
# EPISODE: 272 - FINAL SCORE: 291.72752724464897 - Temperature: 0.026663646948982406
# Updating target network...
# EPISODE: 273 - FINAL SCORE: 272.609071649287 - Temperature: 0.026153626072318793
# Updating target network...
# EPISODE: 274 - FINAL SCORE: -16.32008942009 - Temperature: 0.025653360848928358
# Updating target network...
# EPISODE: 275 - FINAL SCORE: 260.01171715633325 - Temperature: 0.025162664673173685
# Updating target network...
# EPISODE: 276 - FINAL SCORE: 246.6102287805542 - Temperature: 0.024681354508800452
# Updating target network...
# EPISODE: 277 - FINAL SCORE: 114.42036745083574 - Temperature: 0.024209250820662467
# Updating target network...
# EPISODE: 278 - FINAL SCORE: 267.75139863574384 - Temperature: 0.023746177507752625
# Updating target network...
# EPISODE: 279 - FINAL SCORE: 21.04964563839829 - Temperature: 0.023291961837514915
# Updating target network...
# EPISODE: 280 - FINAL SCORE: 273.8941200280706 - Temperature: 0.022846434381412813
# Updating target network...
# EPISODE: 281 - FINAL SCORE: -71.65106713527433 - Temperature: 0.022409428951730186
# Updating target network...
# EPISODE: 282 - FINAL SCORE: 269.88542068586787 - Temperature: 0.021980782539581058
# Updating target network...
# EPISODE: 283 - FINAL SCORE: 255.3232785069964 - Temperature: 0.021560335254105084
# Updating target network...
# EPISODE: 284 - FINAL SCORE: 264.17722467015096 - Temperature: 0.021147930262826135
# Updating target network...
# EPISODE: 285 - FINAL SCORE: 283.6867689100784 - Temperature: 0.02074341373315167
# Updating target network...
# EPISODE: 286 - FINAL SCORE: 54.2118542438337 - Temperature: 0.02034663477499112
# Updating target network...
# EPISODE: 287 - FINAL SCORE: -4.572654338540204 - Temperature: 0.01995744538447185
# Updating target network...
# EPISODE: 288 - FINAL SCORE: -22.485852426789606 - Temperature: 0.019575700388731763
# Updating target network...
# EPISODE: 289 - FINAL SCORE: 250.03282525622876 - Temperature: 0.019201257391767833
# Updating target network...
# EPISODE: 290 - FINAL SCORE: 270.03795448642586 - Temperature: 0.018833976721320506
# Updating target network...
# EPISODE: 291 - FINAL SCORE: 291.5845508211976 - Temperature: 0.01847372137677408
# Updating target network...
# EPISODE: 292 - FINAL SCORE: 272.2962424911749 - Temperature: 0.018120356978053625
# Updating target network...
# EPISODE: 293 - FINAL SCORE: 275.8639042893393 - Temperature: 0.017773751715499424
# Updating target network...
# EPISODE: 294 - FINAL SCORE: 279.31957531134685 - Temperature: 0.0174337763007002
# Updating target network...
# EPISODE: 295 - FINAL SCORE: 283.01850300459364 - Temperature: 0.01710030391826679
# Updating target network...
# EPISODE: 296 - FINAL SCORE: 283.80528605679626 - Temperature: 0.01677321017852833
# Updating target network...
# EPISODE: 297 - FINAL SCORE: -94.9686357952297 - Temperature: 0.016452373071133217
# Updating target network...
# EPISODE: 298 - FINAL SCORE: -0.20316988099051514 - Temperature: 0.016137672919537622
# Updating target network...
# EPISODE: 299 - FINAL SCORE: 257.33783251395744 - Temperature: 0.015828992336364534
# Updating target network...
# EPISODE: 300 - FINAL SCORE: 266.50688189433754 - Temperature: 0.015526216179616692
# Updating target network...
# EPISODE: 301 - FINAL SCORE: 297.9297959431367 - Temperature: 0.015229231509727072
# Updating target network...
# EPISODE: 302 - FINAL SCORE: 287.7806177107501 - Temperature: 0.014937927547430927
# Updating target network...
# EPISODE: 303 - FINAL SCORE: 304.3539844571785 - Temperature: 0.01465219563244362
# Updating target network...
# EPISODE: 304 - FINAL SCORE: 271.1887928505362 - Temperature: 0.014371929182928884
# Updating target network...
# EPISODE: 305 - FINAL SCORE: 260.0409621744293 - Temperature: 0.014097023655742384
# Updating target network...
# EPISODE: 306 - FINAL SCORE: 274.3518200516813 - Temperature: 0.013827376507435696
# Updating target network...
# EPISODE: 307 - FINAL SCORE: 247.83503293158714 - Temperature: 0.013562887156006247
# Updating target network...
# EPISODE: 308 - FINAL SCORE: 281.6142120841183 - Temperature: 0.013303456943378863
# Updating target network...
# EPISODE: 309 - FINAL SCORE: 18.144905248290243 - Temperature: 0.013048989098605001
# Updating target network...
# EPISODE: 310 - FINAL SCORE: 280.0501532438069 - Temperature: 0.012799388701765873
# Updating target network...
# EPISODE: 311 - FINAL SCORE: 294.2513350439343 - Temperature: 0.012554562648566046
# Updating target network...
# EPISODE: 312 - FINAL SCORE: 38.584532453723455 - Temperature: 0.012314419615604298
# Updating target network...
# EPISODE: 313 - FINAL SCORE: 285.67581733632926 - Temperature: 0.012078870026308757
# Updating target network...
# EPISODE: 314 - FINAL SCORE: 283.09069663367336 - Temperature: 0.011847826017523646
# Updating target network...
# EPISODE: 315 - FINAL SCORE: 284.92787426307336 - Temperature: 0.011621201406735136
# Updating target network...
# EPISODE: 316 - FINAL SCORE: 253.22576554114949 - Temperature: 0.011398911659924127
# Updating target network...
# EPISODE: 317 - FINAL SCORE: 256.71757486697 - Temperature: 0.011180873860033911
# Updating target network...
# EPISODE: 318 - FINAL SCORE: -334.3434614019118 - Temperature: 0.010967006676041011
# Updating target network...
# EPISODE: 319 - FINAL SCORE: 257.389693911153 - Temperature: 0.010757230332617605
# Updating target network...
# EPISODE: 320 - FINAL SCORE: 287.0581819349892 - Temperature: 0.010551466580374275
# Updating target network...
# EPISODE: 321 - FINAL SCORE: 272.633293018544 - Temperature: 0.01034963866667192
# Updating target network...
# EPISODE: 322 - FINAL SCORE: 269.54400676295325 - Temperature: 0.010151671306991999
# Updating target network...
# EPISODE: 323 - FINAL SCORE: 292.8078049222348 - Temperature: 0.009957490656854397
# Updating target network...
# EPISODE: 324 - FINAL SCORE: 259.9132017247835 - Temperature: 0.009767024284272442
# Updating target network...
# EPISODE: 325 - FINAL SCORE: 241.33004991666468 - Temperature: 0.009580201142734801
# Updating target network...
# EPISODE: 326 - FINAL SCORE: 274.73565565048807 - Temperature: 0.009396951544704183
# Updating target network...
# EPISODE: 327 - FINAL SCORE: 251.7295931376203 - Temperature: 0.009217207135622948
# Updating target network...
# EPISODE: 328 - FINAL SCORE: 246.90935064105489 - Temperature: 0.009040900868415943
# Updating target network...
# EPISODE: 329 - FINAL SCORE: 290.1189871128155 - Temperature: 0.008867966978481044
# Updating target network...
# EPISODE: 330 - FINAL SCORE: 293.85203123598546 - Temperature: 0.008698340959158078
# Updating target network...
# EPISODE: 331 - FINAL SCORE: 274.9685925444659 - Temperature: 0.008531959537666967
# Updating target network...
# EPISODE: 332 - FINAL SCORE: 243.78712553315052 - Temperature: 0.008368760651506142
# Updating target network...
# EPISODE: 333 - FINAL SCORE: 252.13558152946672 - Temperature: 0.008208683425302395
# Updating target network...
# EPISODE: 334 - FINAL SCORE: 264.67858247853565 - Temperature: 0.008051668148103543
# Updating target network...
# EPISODE: 335 - FINAL SCORE: 269.35394229794116 - Temperature: 0.007897656251105448
# Updating target network...
# EPISODE: 336 - FINAL SCORE: 282.5039216896539 - Temperature: 0.007746590285805065
# Updating target network...
# EPISODE: 337 - FINAL SCORE: 261.3390683835529 - Temperature: 0.007598413902571379
# Updating target network...
# EPISODE: 338 - FINAL SCORE: 207.53183971589272 - Temperature: 0.00745307182962624
# Updating target network...
# EPISODE: 339 - FINAL SCORE: 260.55414181284164 - Temperature: 0.007310509852427246
# Updating target network...
# EPISODE: 340 - FINAL SCORE: 265.26865231582883 - Temperature: 0.007170674793444992
# Updating target network...
# EPISODE: 341 - FINAL SCORE: 249.43475021644247 - Temperature: 0.007033514492327142
# Updating target network...
# EPISODE: 342 - FINAL SCORE: 294.32121921011515 - Temperature: 0.00689897778644191
# Updating target network...
# EPISODE: 343 - FINAL SCORE: 216.79855673027996 - Temperature: 0.006767014491793719
# Updating target network...
# EPISODE: 344 - FINAL SCORE: 273.8478923056672 - Temperature: 0.0066375753843038975
# Updating target network...
# EPISODE: 345 - FINAL SCORE: 226.40816417435792 - Temperature: 0.0065106121814494326
# Updating target network...
# EPISODE: 346 - FINAL SCORE: 242.4820954567099 - Temperature: 0.006386077524252947
# Updating target network...
# EPISODE: 347 - FINAL SCORE: 239.3827851073233 - Temperature: 0.006263924959617164
# Updating target network...
# EPISODE: 348 - FINAL SCORE: 300.9520335111598 - Temperature: 0.006144108922997276
# Updating target network...
# EPISODE: 349 - FINAL SCORE: 304.9448597084036 - Temperature: 0.006026584721404763
# Updating target network...
# EPISODE: 350 - FINAL SCORE: 268.155752089751 - Temperature: 0.005911308516736305
# Updating target network...
# EPISODE: 351 - FINAL SCORE: 269.50411186253143 - Temperature: 0.005798237309421584
# Updating target network...
# EPISODE: 352 - FINAL SCORE: 285.95088397271775 - Temperature: 0.005687328922383864
# Updating target network...
# EPISODE: 353 - FINAL SCORE: 291.27416137141836 - Temperature: 0.00557854198530738
# Updating target network...
# EPISODE: 354 - FINAL SCORE: 241.0904560127223 - Temperature: 0.005471835919205653
# Updating target network...
# EPISODE: 355 - FINAL SCORE: 264.3222391834833 - Temperature: 0.005367170921284983
# Updating target network...
# EPISODE: 356 - FINAL SCORE: 263.06009488439713 - Temperature: 0.005264507950097477
# Updating target network...
# EPISODE: 357 - FINAL SCORE: 263.9498140312219 - Temperature: 0.005163808710978061
# Updating target network...
# EPISODE: 358 - FINAL SCORE: 253.56266371426383 - Temperature: 0.005065035641760057
# Updating target network...
# EPISODE: 359 - FINAL SCORE: 240.20867056017687 - Temperature: 0.004968151898763997
# Updating target network...
# EPISODE: 360 - FINAL SCORE: 282.3817336091822 - Temperature: 0.004873121343054426
# Updating target network...
# EPISODE: 361 - FINAL SCORE: 282.23763013085284 - Temperature: 0.004779908526959604
# Updating target network...
# EPISODE: 362 - FINAL SCORE: 277.7202498562682 - Temperature: 0.0046884786808490415
# Updating target network...
# EPISODE: 363 - FINAL SCORE: 307.01177748899084 - Temperature: 0.004598797700163969
# Updating target network...
# EPISODE: 364 - FINAL SCORE: 297.0026039412238 - Temperature: 0.004510832132695872
# Updating target network...
# EPISODE: 365 - FINAL SCORE: 275.2964471696919 - Temperature: 0.004424549166108372
# Updating target network...
# EPISODE: 366 - FINAL SCORE: 265.9960026479017 - Temperature: 0.004339916615697785
# Updating target network...
# EPISODE: 367 - FINAL SCORE: 305.25336248761283 - Temperature: 0.0042569029123877946
# Updating target network...
# EPISODE: 368 - FINAL SCORE: 279.01995340993454 - Temperature: 0.004175477090953762
# Updating target network...
# EPISODE: 369 - FINAL SCORE: 244.0850672197144 - Temperature: 0.004095608778472287
# Updating target network...
# EPISODE: 370 - FINAL SCORE: 251.6754863241396 - Temperature: 0.004017268182991692
# Updating target network...
# EPISODE: 371 - FINAL SCORE: 262.348462632356 - Temperature: 0.003940426082419233
# Updating target network...
# EPISODE: 372 - FINAL SCORE: 263.56992998470497 - Temperature: 0.00386505381362086
# Updating target network...
# EPISODE: 373 - FINAL SCORE: 246.42138579095698 - Temperature: 0.0037911232617294888
# Updating target network...
# EPISODE: 374 - FINAL SCORE: 265.17502967867927 - Temperature: 0.0037186068496577753
# Updating target network...
# EPISODE: 375 - FINAL SCORE: 255.4267385458322 - Temperature: 0.0036474775278114943
# Updating target network...
# EPISODE: 376 - FINAL SCORE: 279.19997445388253 - Temperature: 0.0035777087639996766
# Updating target network...
# EPISODE: 377 - FINAL SCORE: 283.2892249082457 - Temperature: 0.0035092745335377467
# Updating target network...
# EPISODE: 378 - FINAL SCORE: 237.68135842726207 - Temperature: 0.0034421493095399647
# Updating target network...
# EPISODE: 379 - FINAL SCORE: 304.75274388367257 - Temperature: 0.0033763080533975596
# Updating target network...
# EPISODE: 380 - FINAL SCORE: 277.1461050769045 - Temperature: 0.0033117262054389866
# Updating target network...
# EPISODE: 381 - FINAL SCORE: 294.1184115750303 - Temperature: 0.0032483796757688467
# Updating target network...
# EPISODE: 382 - FINAL SCORE: 225.59452493788766 - Temperature: 0.0031862448352820275
# Updating target network...
# EPISODE: 383 - FINAL SCORE: 282.9213395956142 - Temperature: 0.003125298506849732
# Updating target network...
# EPISODE: 384 - FINAL SCORE: 279.9868740503264 - Temperature: 0.0030655179566741
# Updating target network...
# EPISODE: 385 - FINAL SCORE: -384.146874770814 - Temperature: 0.0030068808858081946
# Updating target network...
# EPISODE: 386 - FINAL SCORE: 249.95030655834708 - Temperature: 0.002949365421838196
# Updating target network...
# EPISODE: 387 - FINAL SCORE: 267.3095527202519 - Temperature: 0.0028929501107247
# Updating target network...
# EPISODE: 388 - FINAL SCORE: 133.93296180627308 - Temperature: 0.0028376139088000713
# Updating target network...
# EPISODE: 389 - FINAL SCORE: 248.39072385888753 - Temperature: 0.0027833361749188736
# Updating target network...
# EPISODE: 390 - FINAL SCORE: 270.11846649403896 - Temperature: 0.002730096662758447
# Updating target network...
# EPISODE: 391 - FINAL SCORE: 248.36569735784735 - Temperature: 0.002677875513266757
# Updating target network...
# EPISODE: 392 - FINAL SCORE: 243.30318479805715 - Temperature: 0.0026266532472547003
# Updating target network...
# EPISODE: 393 - FINAL SCORE: 259.1794733000125 - Temperature: 0.0025764107581301102
# Updating target network...
# EPISODE: 394 - FINAL SCORE: 261.4979777755111 - Temperature: 0.0025271293047707363
# Updating target network...
# EPISODE: 395 - FINAL SCORE: 297.9234803545211 - Temperature: 0.002478790504533559
# Updating target network...
# EPISODE: 396 - FINAL SCORE: 261.97134948161954 - Temperature: 0.002431376326397815
# Updating target network...
# EPISODE: 397 - FINAL SCORE: 282.96802341680336 - Temperature: 0.0023848690842391837
# Updating target network...
# EPISODE: 398 - FINAL SCORE: 281.5097837677211 - Temperature: 0.0023392514302326287
# Updating target network...
# EPISODE: 399 - FINAL SCORE: 291.3837101702271 - Temperature: 0.0022945063483814235
# Updating target network...
# EPISODE: 400 - FINAL SCORE: 251.97894134336167 - Temperature: 0.0022506171481699584
# Updating target network...
# EPISODE: 401 - FINAL SCORE: 293.0019639615664 - Temperature: 0.0022075674583379523
# Updating target network...
# EPISODE: 402 - FINAL SCORE: 246.62896341633035 - Temperature: 0.0021653412207737564
# Updating target network...
# EPISODE: 403 - FINAL SCORE: 300.9385840718936 - Temperature: 0.002123922684524459
# Updating target network...
# EPISODE: 404 - FINAL SCORE: 268.4076152414959 - Temperature: 0.002083296399920573
# Updating target network...
# EPISODE: 405 - FINAL SCORE: 284.6883101461025 - Temperature: 0.0020434472128130986
# Updating target network...
# EPISODE: 406 - FINAL SCORE: 252.7476806450986 - Temperature: 0.002004360258920824
# Updating target network...
# EPISODE: 407 - FINAL SCORE: 246.30267245537226 - Temperature: 0.001966020958285751
# Updating target network...
# EPISODE: 408 - FINAL SCORE: 289.7495340057469 - Temperature: 0.0019284150098345695
# Updating target network...
# EPISODE: 409 - FINAL SCORE: 287.6498284360713 - Temperature: 0.0018915283860441718
# Updating target network...
# EPISODE: 410 - FINAL SCORE: 245.47364075267205 - Temperature: 0.0018553473277091949
# Updating target network...
# EPISODE: 411 - FINAL SCORE: 279.8500337682568 - Temperature: 0.0018198583388096532
# Updating target network...
# EPISODE: 412 - FINAL SCORE: 255.61420478019602 - Temperature: 0.0017850481814767419
# Updating target network...
# EPISODE: 413 - FINAL SCORE: 197.158242981795 - Temperature: 0.0017509038710549337
# Updating target network...
# EPISODE: 414 - FINAL SCORE: 287.17100608674787 - Temperature: 0.0017174126712585294
# Updating target network...
# EPISODE: 415 - FINAL SCORE: 289.1276537797454 - Temperature: 0.0016845620894208524
# Updating target network...
# EPISODE: 416 - FINAL SCORE: 33.805050611501 - Temperature: 0.0016523398718343157
# Updating target network...
# EPISODE: 417 - FINAL SCORE: 246.8043192537298 - Temperature: 0.0016207339991796245
# Updating target network...
# EPISODE: 418 - FINAL SCORE: 296.0482464937562 - Temperature: 0.0015897326820424108
# Updating target network...
# EPISODE: 419 - FINAL SCORE: 207.19109289752475 - Temperature: 0.0015593243565156201
# Updating target network...
# EPISODE: 420 - FINAL SCORE: 272.1982781113207 - Temperature: 0.0015294976798860239
# Updating target network...
# EPISODE: 421 - FINAL SCORE: 222.32587865615935 - Temperature: 0.0015002415264032311
# Updating target network...
# EPISODE: 422 - FINAL SCORE: 245.42034341109635 - Temperature: 0.001471544983129636
# Updating target network...
# EPISODE: 423 - FINAL SCORE: 266.823830722418 - Temperature: 0.0014433973458697464
# Updating target network...
# EPISODE: 424 - FINAL SCORE: 273.1353213727103 - Temperature: 0.0014157881151773742
# Updating target network...
# EPISODE: 425 - FINAL SCORE: 293.89605014789925 - Temperature: 0.001388706992439202
# Updating target network...
# EPISODE: 426 - FINAL SCORE: 264.8554849699839 - Temperature: 0.001362143876033261
# Updating target network...
# EPISODE: 427 - FINAL SCORE: 241.45520182458037 - Temperature: 0.0013360888575608923
# Updating target network...
# EPISODE: 428 - FINAL SCORE: 285.2938003836566 - Temperature: 0.0013105322181507797
# Updating target network...
# EPISODE: 429 - FINAL SCORE: 259.10826160029865 - Temperature: 0.0012854644248336813
# Updating target network...
# EPISODE: 430 - FINAL SCORE: 279.2904283419269 - Temperature: 0.0012608761269865044
# Updating target network...
# EPISODE: 431 - FINAL SCORE: 238.8911394544008 - Temperature: 0.0012367581528443953
# Updating target network...
# EPISODE: 432 - FINAL SCORE: 29.13643656309324 - Temperature: 0.001213101506079552
# Updating target network...
# EPISODE: 433 - FINAL SCORE: 258.36586982089494 - Temperature: 0.00118989736244547
# Updating target network...
# EPISODE: 434 - FINAL SCORE: 249.06848779869728 - Temperature: 0.0011671370664853812
# Updating target network...
# EPISODE: 435 - FINAL SCORE: 294.103539697919 - Temperature: 0.0011448121283036525
# Updating target network...
# EPISODE: 436 - FINAL SCORE: 299.2803914109621 - Temperature: 0.0011229142203989407
# Updating target network...
# EPISODE: 437 - FINAL SCORE: 290.0043747867768 - Temperature: 0.001101435174557923
# Updating target network...
# EPISODE: 438 - FINAL SCORE: 294.0475389759148 - Temperature: 0.0010803669788084437
# Updating target network...
# EPISODE: 439 - FINAL SCORE: 255.99747723614817 - Temperature: 0.0010597017744309407
# Updating target network...
# EPISODE: 440 - FINAL SCORE: 61.702778059029896 - Temperature: 0.0010394318530270391
# Updating target network...
# EPISODE: 441 - FINAL SCORE: 271.69167665824966 - Temperature: 0.0010195496536442136
# Updating target network...
# EPISODE: 442 - FINAL SCORE: 20.14124453798273 - Temperature: 0.001000047759955453
# Updating target network...
# EPISODE: 443 - FINAL SCORE: 46.92498569121534 - Temperature: 0.0009809188974928698
# Updating target network...
# EPISODE: 444 - FINAL SCORE: 242.76952573377437 - Temperature: 0.0009621559309342268
# Updating target network...
# EPISODE: 445 - FINAL SCORE: 301.71717013582565 - Temperature: 0.0009437518614413663
# Updating target network...
# EPISODE: 446 - FINAL SCORE: 292.83305368186285 - Temperature: 0.0009256998240495493
# Updating target network...
# EPISODE: 447 - FINAL SCORE: 243.74881532530264 - Temperature: 0.000907993085106731
# Updating target network...
# EPISODE: 448 - FINAL SCORE: 244.4658553855403 - Temperature: 0.0008906250397618196
# Updating target network...
# EPISODE: 449 - FINAL SCORE: 304.8878335875191 - Temperature: 0.0008735892095009775
# Updating target network...
# EPISODE: 450 - FINAL SCORE: 252.61214652575154 - Temperature: 0.0008568792397310482
# Updating target network...
# EPISODE: 451 - FINAL SCORE: 275.0441489105747 - Temperature: 0.0008404888974092091
# Updating target network...
# EPISODE: 452 - FINAL SCORE: 252.05638276748823 - Temperature: 0.0008244120687179624
# Updating target network...
# EPISODE: 453 - FINAL SCORE: 304.39859893646735 - Temperature: 0.0008086427567845981
# Updating target network...
# EPISODE: 454 - FINAL SCORE: 45.687249500705605 - Temperature: 0.0007931750794442822
# Updating target network...
# EPISODE: 455 - FINAL SCORE: 285.65768742253306 - Temperature: 0.0007780032670459283
# Updating target network...
# EPISODE: 456 - FINAL SCORE: 28.22874840861735 - Temperature: 0.0007631216603000415
# Updating target network...
# EPISODE: 457 - FINAL SCORE: 247.0571967856402 - Temperature: 0.0007485247081677275
# Updating target network...
# EPISODE: 458 - FINAL SCORE: 285.12526626160695 - Temperature: 0.0007342069657900799
# Updating target network...
# EPISODE: 459 - FINAL SCORE: 253.0778959520862 - Temperature: 0.0007201630924571756
# Updating target network...
# EPISODE: 460 - FINAL SCORE: 257.6725837409109 - Temperature: 0.0007063878496159181
# Updating target network...
# EPISODE: 461 - FINAL SCORE: 278.2866850631434 - Temperature: 0.0006928760989159868
# Updating target network...
# EPISODE: 462 - FINAL SCORE: 262.8667196420085 - Temperature: 0.0006796228002931634
# Updating target network...
# EPISODE: 463 - FINAL SCORE: 234.15167315893862 - Temperature: 0.0006666230100893208
# Updating target network...
# EPISODE: 464 - FINAL SCORE: 266.8789584841948 - Temperature: 0.0006538718792083719
# Updating target network...
# EPISODE: 465 - FINAL SCORE: 257.432452963539 - Temperature: 0.0006413646513074915
# Updating target network...
# EPISODE: 466 - FINAL SCORE: 283.68152676661373 - Temperature: 0.0006290966610229373
# Updating target network...
# EPISODE: 467 - FINAL SCORE: 290.1223888508647 - Temperature: 0.0006170633322298063
# Updating target network...
# EPISODE: 468 - FINAL SCORE: 288.9490364447234 - Temperature: 0.0006052601763350787
# Updating target network...
# EPISODE: 469 - FINAL SCORE: 258.38872217603205 - Temperature: 0.000593682790603313
# Updating target network...
# EPISODE: 470 - FINAL SCORE: 268.37992626622827 - Temperature: 0.0005823268565143657
# Updating target network...
# EPISODE: 471 - FINAL SCORE: 279.7739033039045 - Temperature: 0.0005711881381525268
# Updating target network...
# EPISODE: 472 - FINAL SCORE: 17.180841359791472 - Temperature: 0.0005602624806264648
# Updating target network...
# EPISODE: 473 - FINAL SCORE: 251.94945635261126 - Temperature: 0.0005495458085193979
# Updating target network...
# EPISODE: 474 - FINAL SCORE: 298.6299464947913 - Temperature: 0.000539034124368908
# Updating target network...
# EPISODE: 475 - FINAL SCORE: 285.7896945610056 - Temperature: 0.0005287235071758339
# Updating target network...
# EPISODE: 476 - FINAL SCORE: 297.5165908178327 - Temperature: 0.0005186101109416865
# Updating target network...
# EPISODE: 477 - FINAL SCORE: 262.52003662670876 - Temperature: 0.0005086901632340385
# Updating target network...
# EPISODE: 478 - FINAL SCORE: -55.67369128122934 - Temperature: 0.000498959963779358
# Updating target network...
# EPISODE: 479 - FINAL SCORE: 274.50798446849 - Temperature: 0.0004894158830827561
# Updating target network...
# EPISODE: 480 - FINAL SCORE: 234.39815053541963 - Temperature: 0.0004800543610741364
# Updating target network...
# EPISODE: 481 - FINAL SCORE: 257.51891218349783 - Temperature: 0.0004708719057802418
# Updating target network...
# EPISODE: 482 - FINAL SCORE: -40.85984746543174 - Temperature: 0.0004618650920221009
# Updating target network...
# EPISODE: 483 - FINAL SCORE: 283.3373897317957 - Temperature: 0.0004530305601373911
# Updating target network...
# EPISODE: 484 - FINAL SCORE: 313.55265077849435 - Temperature: 0.0004443650147272386
# Updating target network...
# EPISODE: 485 - FINAL SCORE: -33.25938660994808 - Temperature: 0.00043586522342699133
# Updating target network...
# EPISODE: 486 - FINAL SCORE: 278.3410180415343 - Temperature: 0.0004275280157005029
# Updating target network...
# EPISODE: 487 - FINAL SCORE: 266.1359273330712 - Temperature: 0.00041935028165748046
# Updating target network...
# EPISODE: 488 - FINAL SCORE: 310.4696071605217 - Temperature: 0.0004113289708934537
# Updating target network...
# EPISODE: 489 - FINAL SCORE: 240.1708844932434 - Temperature: 0.0004034610913519334
# Updating target network...
# EPISODE: 490 - FINAL SCORE: 253.1665022642583 - Temperature: 0.0003957437082083336
# Updating target network...
# EPISODE: 491 - FINAL SCORE: 259.08810589568384 - Temperature: 0.00038817394277524363
# Updating target network...
# EPISODE: 492 - FINAL SCORE: 261.9550111271378 - Temperature: 0.00038074897142863803
# Updating target network...
# EPISODE: 493 - FINAL SCORE: 274.2624616176097 - Temperature: 0.0003734660245546279
# Updating target network...
# EPISODE: 494 - FINAL SCORE: 290.32678926229323 - Temperature: 0.0003663223855163569
# Updating target network...
# EPISODE: 495 - FINAL SCORE: 275.96643320342514 - Temperature: 0.00035931538964066004
# Updating target network...
# EPISODE: 496 - FINAL SCORE: 46.542022400567504 - Temperature: 0.0003524424232241042
# Updating target network...
# EPISODE: 497 - FINAL SCORE: 252.16328700067882 - Temperature: 0.0003457009225580422
# Updating target network...
# EPISODE: 498 - FINAL SCORE: 246.96766467658983 - Temperature: 0.00033908837297231496
# Updating target network...
# EPISODE: 499 - FINAL SCORE: 234.68439863676883 - Temperature: 0.00033260230789724544
# Updating target network...
# EPISODE: 500 - FINAL SCORE: 264.9812618491969 - Temperature: 0.0003262403079435757
# Text(0, 0.5, 'Scores')

# %% [markdown]
# ## Final test

# %%
# Initialize the Gym environment
env = gym.make('LunarLander-v2') 
env.seed(5) # Set a random seed for the environment (reproducible results)
scores100= []
# This is for creating the output video in Colab, not required outside Colab
#env = wrap_env(env, video_callable=lambda episode_id: True) # Save a video every episode

# Let's try for a total of 10 episodes
for num_episode in range(100): 
    # Reset the environment and get the initial state
    state = env.reset()
    # Reset the score. The final score will be the total amount of steps before the pole falls
    score = 0
    done = False
    while not done:
      # Choose the best action (temperature 0)
      action, q_values = choose_action_softmax(policy_net, state, temperature=0)
      # Apply the action and get the next state, the reward and a flag "done" that is True if the game is ended
      next_state, reward, done, info = env.step(action)
      score += reward 
      # Set the current state for the next iteration
      state = next_state
      # Check if the episode ended (the pole fell down)
    # Print the final score
    #print(f"EPISODE {num_episode + 1} - FINAL SCORE: {score}") 
    scores100.append(score)
env.close()

# %%
# Mean on 100 trials
print(np.mean(scores100))
# Out:
# 182.6253318728425
